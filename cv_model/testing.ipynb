# %%
from stitch import SuperGlow

# %%
super_glow = SuperGlow()

# %%
img = super_glow.connect_photos(photos=['I:\\repos\\CVNapoleon\\hack_stitch_dataset\\hack_stitch_dataset\\2\\photo_2024-03-13 11.12.03.jpeg',
                                       'I:\\repos\\CVNapoleon\\hack_stitch_dataset\\hack_stitch_dataset\\2\\photo_2024-03-13 11.12.04.jpeg'])
# Out:
# 0: 608x1280 34 products, 519.9ms
# Speed: 10.5ms preprocess, 519.9ms inference, 2281.5ms postprocess per image at shape (1, 3, 608, 1280)
# Results saved to i:\repos\CVNapoleon\runs\detect\predict23
#
# 0: 576x1280 1 empty, 36 products, 497.7ms
# Speed: 7.5ms preprocess, 497.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 1280)
# Results saved to i:\repos\CVNapoleon\runs\detect\predict23
#
# 0: 576x1280 35 products, 491.7ms
# Speed: 10.0ms preprocess, 491.7ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1280)
# Results saved to i:\repos\CVNapoleon\runs\detect\predict23
#
# 0: 608x1280 34 products, 566.8ms
# Speed: 9.1ms preprocess, 566.8ms inference, 1.6ms postprocess per image at shape (1, 3, 608, 1280)
# Results saved to i:\repos\CVNapoleon\runs\detect\predict23
#
# 0: 608x1280 34 products, 697.3ms
# Speed: 11.1ms preprocess, 697.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 1280)
# ...

# %%
super_glow.show(img)
